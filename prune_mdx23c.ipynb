# %%
import torch
import copy
import numpy as np
from tqdm import tqdm
import os
from utils.prune_utils.concern_identification import ConcernIdentification
from utils.prune_utils.weight_remover import WeightRemover
from utils.dataset import download_musdb, load_data
from utils.train import train_model, valid, load_not_compatible_weights, get_model_from_config
from utils.config_utils import load_config

# %%
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.deterministic = False  # Fix possible slow down with dilation convolutions
torch.multiprocessing.set_start_method('spawn')
train_data, test_data = download_musdb()

# %%
device = 'cuda:0'
cfg = load_config('train_config.yaml')
cfg.model_type = 'mdx23c'
cfg.config_path = 'Configs/mdx23c_config.yaml'
cfg.results_path = 'Results/'
cfg.data_path = 'Datasets/musdb18hq/train'
cfg.num_workers = 0
cfg.valid_path = 'Datasets/musdb18hq/valid'
cfg.seed = 44
cfg.start_check_point = 'Results/model_mdx23c(before prune).ckpt'

# %%
mdx23c, mdx23c_config = get_model_from_config(cfg.model_type, cfg.config_path)
load_not_compatible_weights(mdx23c, cfg.start_check_point, verbose=False)
mdx23c = mdx23c.to(device)

train_dataloader, valid_dataloader, test_dataloader = load_data(mdx23c_config, cfg, 2)
mdx23c = mdx23c.to(device)
valid(mdx23c, cfg, mdx23c_config, device)
ref_mdx23c = copy.deepcopy(mdx23c)
weight_remover = WeightRemover(mdx23c, device, 0.8)
# Out:
# Use augmentation for training
# Loading songs data from cache: Results/metadata_train.pkl. If you updated dataset remove metadata_train.pkl before training!
# Found tracks in dataset: 80
# Use augmentation for training
# Loading songs data from cache: Results/metadata_valid.pkl. If you updated dataset remove metadata_valid.pkl before training!
# Found tracks in dataset: 20
# Use augmentation for training
# Loading songs data from cache: Results/metadata_test.pkl. If you updated dataset remove metadata_test.pkl before training!
# Found tracks in dataset: 50
# 100%|██████████| 20/20 [04:57<00:00, 14.87s/it, sdr_vocals=8.22, sdr_other=19.2]
# Instr SDR vocals: 11.3885
# Instr SDR other: 17.8419
# SDR Avg: 14.6152

# %%
print("start pruning")
for idx in range(10):
    tr = torch.tensor(np.random.rand(2, 2, 261120), dtype=torch.float32).to(device)
    with torch.no_grad():
        y_ = weight_remover.process(tr)
    weight_remover.apply_removal()
valid(mdx23c, cfg, mdx23c_config, device)
# Out:
# start pruning
# before 262144
# after 235270
# before 262144
# after 236813
# before 262144
# after 235857
# before 262144
# after 236601
# before 65536
# after 58728
# before 65536
# after 59277
# before 65536
# after 58787
# before 65536
# after 59124
# before 16384
# after 14617
# before 16384
# after 14814
# before 16384
# after 14385
# before 16384
# after 14797
# before 4096
# after 3682
# before 4096
# after 3729
# before 4096
# after 3673
# before 4096
# after 3730
# before 1024
# after 940
# before 1024
# after 937
# before 1024
# after 932
# before 1024
# after 953
# before 256
# after 235
# before 256
# after 235
# before 256
# after 241
# before 256
# after 239
# before 1024
# after 937
# before 1024
# after 947
# before 1024
# after 932
# before 1024
# after 943
# before 4096
# after 3696
# before 4096
# after 3754
# before 4096
# after 3669
# before 4096
# after 3707
# before 16384
# after 14545
# before 16384
# after 14768
# before 16384
# after 14603
# before 16384
# after 14819
# before 65536
# after 57795
# before 65536
# after 58814
# before 65536
# after 57423
# before 65536
# after 58749
# before 262144
# after 231605
# before 262144
# after 232939
# before 262144
# after 233914
# before 262144
# after 230928
# before 235270
# after 234305
# before 236813
# after 235709
# before 235857
# after 234922
# before 236601
# after 235035
# before 58728
# after 58437
# before 59277
# after 58837
# before 58787
# after 58585
# before 59124
# after 58890
# before 14617
# after 14473
# before 14814
# after 14753
# before 14385
# after 14299
# before 14797
# after 14643
# before 3682
# after 3647
# before 3729
# after 3710
# before 3673
# after 3658
# before 3730
# after 3703
# before 940
# after 939
# before 937
# after 927
# before 932
# after 923
# before 953
# after 949
# before 235
# after 233
# before 235
# after 234
# before 241
# after 240
# before 239
# after 238
# before 937
# after 929
# before 947
# after 942
# before 932
# after 920
# before 943
# after 938
# before 3696
# after 3670
# before 3754
# after 3735
# before 3669
# after 3620
# before 3707
# after 3639
# before 14545
# after 14467
# before 14768
# after 14611
# before 14603
# after 14556
# before 14819
# after 14683
# before 57795
# after 57560
# before 58814
# after 58523
# before 57423
# after 56971
# before 58749
# after 58444
# before 231605
# after 230579
# before 232939
# after 231082
# before 233914
# after 233564
# before 230928
# after 228748
# before 234305
# after 234237
# before 235709
# after 235638
# before 234922
# after 234908
# before 235035
# after 234918
# before 58437
# after 58422
# before 58837
# after 58801
# before 58585
# after 58583
# before 58890
# after 58888
# before 14473
# after 14465
# before 14753
# after 14751
# before 14299
# after 14297
# before 14643
# after 14639
# before 3647
# after 3645
# before 3710
# after 3710
# before 3658
# after 3658
# before 3703
# after 3699
# before 939
# after 939
# before 927
# after 925
# before 923
# after 922
# before 949
# after 949
# before 233
# after 233
# before 234
# after 234
# before 240
# after 240
# before 238
# after 238
# before 929
# after 925
# before 942
# after 942
# before 920
# after 919
# before 938
# after 937
# before 3670
# after 3667
# before 3735
# after 3731
# before 3620
# after 3611
# before 3639
# after 3629
# before 14467
# after 14464
# before 14611
# after 14602
# before 14556
# after 14556
# before 14683
# after 14671
# before 57560
# after 57556
# before 58523
# after 58512
# before 56971
# after 56950
# before 58444
# after 58431
# before 230579
# after 230566
# before 231082
# after 231061
# before 233564
# after 233563
# before 228748
# after 228612
# before 234237
# after 234227
# before 235638
# after 235622
# before 234908
# after 234905
# before 234918
# after 234893
# before 58422
# after 58420
# before 58801
# after 58789
# before 58583
# after 58583
# before 58888
# after 58888
# before 14465
# after 14465
# before 14751
# after 14751
# before 14297
# after 14297
# before 14639
# after 14639
# before 3645
# after 3645
# before 3710
# after 3710
# before 3658
# after 3658
# before 3699
# after 3699
# before 939
# after 939
# before 925
# after 925
# before 922
# after 922
# before 949
# after 949
# before 233
# after 233
# before 234
# after 234
# before 240
# after 240
# before 238
# after 238
# before 925
# after 923
# before 942
# after 942
# before 919
# after 918
# before 937
# after 937
# before 3667
# after 3667
# before 3731
# after 3731
# before 3611
# after 3608
# before 3629
# after 3626
# before 14464
# after 14463
# before 14602
# after 14601
# before 14556
# after 14556
# before 14671
# after 14667
# before 57556
# after 57555
# before 58512
# after 58512
# before 56950
# after 56945
# before 58431
# after 58428
# before 230566
# after 230564
# before 231061
# after 231060
# before 233563
# after 233563
# before 228612
# after 228594
# before 234227
# after 234226
# before 235622
# after 235614
# before 234905
# after 234904
# before 234893
# after 234892
# before 58420
# after 58419
# before 58789
# after 58783
# before 58583
# after 58583
# before 58888
# after 58888
# before 14465
# after 14465
# before 14751
# after 14751
# before 14297
# after 14297
# before 14639
# after 14639
# before 3645
# after 3645
# before 3710
# after 3710
# before 3658
# after 3658
# before 3699
# after 3699
# before 939
# after 939
# before 925
# after 925
# before 922
# after 922
# before 949
# after 949
# before 233
# after 233
# before 234
# after 234
# before 240
# after 240
# before 238
# after 238
# before 923
# after 922
# before 942
# after 942
# before 918
# after 917
# before 937
# after 937
# before 3667
# after 3667
# before 3731
# after 3731
# before 3608
# after 3608
# before 3626
# after 3626
# before 14463
# after 14463
# before 14601
# after 14601
# before 14556
# after 14556
# before 14667
# after 14664
# before 57555
# after 57555
# before 58512
# after 58512
# before 56945
# after 56945
# before 58428
# after 58428
# before 230564
# after 230564
# before 231060
# after 231059
# before 233563
# after 233563
# before 228594
# after 228592
# before 234226
# after 234226
# before 235614
# after 235613
# before 234904
# after 234904
# before 234892
# after 234891
# before 58419
# after 58419
# before 58783
# after 58781
# before 58583
# after 58583
# before 58888
# after 58888
# before 14465
# after 14465
# before 14751
# after 14751
# before 14297
# after 14297
# before 14639
# after 14639
# before 3645
# after 3645
# before 3710
# after 3710
# before 3658
# after 3658
# before 3699
# after 3699
# before 939
# after 939
# before 925
# after 925
# before 922
# after 922
# before 949
# after 949
# before 233
# after 233
# before 234
# after 234
# before 240
# after 240
# before 238
# after 238
# before 922
# after 920
# before 942
# after 942
# before 917
# after 916
# before 937
# after 937
# before 3667
# after 3667
# before 3731
# after 3731
# before 3608
# after 3608
# before 3626
# after 3626
# before 14463
# after 14463
# before 14601
# after 14601
# before 14556
# after 14556
# before 14664
# after 14664
# before 57555
# after 57555
# before 58512
# after 58512
# before 56945
# after 56945
# before 58428
# after 58428
# before 230564
# after 230564
# before 231059
# after 231059
# before 233563
# after 233563
# before 228592
# after 228592
# before 234226
# after 234226
# before 235613
# after 235611
# before 234904
# after 234904
# before 234891
# after 234891
# before 58419
# after 58419
# before 58781
# after 58780
# before 58583
# after 58583
# before 58888
# after 58888
# before 14465
# after 14465
# before 14751
# after 14751
# before 14297
# after 14297
# before 14639
# after 14639
# before 3645
# after 3645
# before 3710
# after 3710
# before 3658
# after 3658
# before 3699
# after 3699
# before 939
# after 939
# before 925
# after 925
# before 922
# after 922
# before 949
# after 949
# before 233
# after 233
# before 234
# after 234
# before 240
# after 240
# before 238
# after 238
# before 920
# after 918
# before 942
# after 942
# before 916
# after 916
# before 937
# after 937
# before 3667
# after 3667
# before 3731
# after 3731
# before 3608
# after 3608
# before 3626
# after 3626
# before 14463
# after 14463
# before 14601
# after 14601
# before 14556
# after 14556
# before 14664
# after 14664
# before 57555
# after 57555
# before 58512
# after 58512
# before 56945
# after 56945
# before 58428
# after 58428
# before 230564
# after 230564
# before 231059
# after 231059
# before 233563
# after 233563
# before 228592
# after 228592
# before 234226
# after 234226
# before 235611
# after 235611
# before 234904
# after 234904
# before 234891
# after 234891
# before 58419
# after 58419
# before 58780
# after 58778
# before 58583
# after 58583
# before 58888
# after 58888
# before 14465
# after 14465
# before 14751
# after 14751
# before 14297
# after 14297
# before 14639
# after 14639
# before 3645
# after 3645
# before 3710
# after 3710
# before 3658
# after 3658
# before 3699
# after 3699
# before 939
# after 939
# before 925
# after 925
# before 922
# after 922
# before 949
# after 949
# before 233
# after 233
# before 234
# after 234
# before 240
# after 240
# before 238
# after 238
# before 918
# after 918
# before 942
# after 942
# before 916
# after 916
# before 937
# after 937
# before 3667
# after 3667
# before 3731
# after 3731
# before 3608
# after 3608
# before 3626
# after 3626
# before 14463
# after 14463
# before 14601
# after 14601
# before 14556
# after 14556
# before 14664
# after 14664
# before 57555
# after 57555
# before 58512
# after 58512
# before 56945
# after 56945
# before 58428
# after 58428
# before 230564
# after 230564
# before 231059
# after 231059
# before 233563
# after 233563
# before 228592
# after 228592
# before 234226
# after 234226
# before 235611
# after 235611
# before 234904
# after 234904
# before 234891
# after 234891
# before 58419
# after 58419
# before 58778
# after 58777
# before 58583
# after 58583
# before 58888
# after 58888
# before 14465
# after 14465
# before 14751
# after 14751
# before 14297
# after 14297
# before 14639
# after 14639
# before 3645
# after 3645
# before 3710
# after 3710
# before 3658
# after 3658
# before 3699
# after 3699
# before 939
# after 939
# before 925
# after 925
# before 922
# after 922
# before 949
# after 949
# before 233
# after 233
# before 234
# after 234
# before 240
# after 240
# before 238
# after 238
# before 918
# after 918
# before 942
# after 942
# before 916
# after 916
# before 937
# after 937
# before 3667
# after 3667
# before 3731
# after 3731
# before 3608
# after 3608
# before 3626
# after 3626
# before 14463
# after 14463
# before 14601
# after 14601
# before 14556
# after 14556
# before 14664
# after 14664
# before 57555
# after 57555
# before 58512
# after 58512
# before 56945
# after 56945
# before 58428
# after 58428
# before 230564
# after 230564
# before 231059
# after 231059
# before 233563
# after 233563
# before 228592
# after 228592
# before 234226
# after 234226
# before 235611
# after 235611
# before 234904
# after 234904
# before 234891
# after 234891
# before 58419
# after 58419
# before 58777
# after 58776
# before 58583
# after 58583
# before 58888
# after 58888
# before 14465
# after 14465
# before 14751
# after 14751
# before 14297
# after 14297
# before 14639
# after 14639
# before 3645
# after 3645
# before 3710
# after 3710
# before 3658
# after 3658
# before 3699
# after 3699
# before 939
# after 939
# before 925
# after 925
# before 922
# after 922
# before 949
# after 949
# before 233
# after 233
# before 234
# after 234
# before 240
# after 240
# before 238
# after 238
# before 918
# after 918
# before 942
# after 942
# before 916
# after 916
# before 937
# after 937
# before 3667
# after 3667
# before 3731
# after 3731
# before 3608
# after 3608
# before 3626
# after 3626
# before 14463
# after 14463
# before 14601
# after 14601
# before 14556
# after 14556
# before 14664
# after 14664
# before 57555
# after 57555
# before 58512
# after 58512
# before 56945
# after 56945
# before 58428
# after 58428
# before 230564
# after 230564
# before 231059
# after 231059
# before 233563
# after 233563
# before 228592
# after 228592
# 100%|██████████| 20/20 [05:08<00:00, 15.43s/it, sdr_vocals=8.19, sdr_other=19.1]
# Instr SDR vocals: 11.3138
# Instr SDR other: 17.7662
# SDR Avg: 14.5400
# 14.5400019747205

# %%
print("CI")
ci = ConcernIdentification(ref_mdx23c, mdx23c, device, 0.4)
_, temp_config = get_model_from_config(cfg.model_type, cfg.config_path)
temp_config.training.instruments = ["vocals"]
temp_dataloader, _, _ = load_data(temp_config, cfg, 2)
# Out:
# CI
# Use augmentation for training
# Loading songs data from cache: Results/metadata_train.pkl. If you updated dataset remove metadata_train.pkl before training!
# Found tracks in dataset: 80
# Use augmentation for training
# Loading songs data from cache: Results/metadata_valid.pkl. If you updated dataset remove metadata_valid.pkl before training!
# Found tracks in dataset: 20
# Use augmentation for training
# Loading songs data from cache: Results/metadata_test.pkl. If you updated dataset remove metadata_test.pkl before training!
# Found tracks in dataset: 50

# %%
pbar = tqdm(temp_dataloader)
for i, (batch, mixes) in enumerate(pbar):
    y = batch.to(device)
    x = mixes.to(device)
    with torch.no_grad():
        ci.process(x)
    ci.apply_prune()
    if i > 100:
        break
# Out:
#   0%|          | 0/1000 [00:04<?, ?it/s]
# before 234226
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 7
#       5 with torch.no_grad():
#       6     ci.process(x)
# ----> 7 ci.apply_prune()
#       8 if i > 100:
#       9     break
#
# File ~/Github/DiscoverVoice/SuperDemucs/utils/prune_utils/concern_identification.py:141, in ConcernIdentification.apply_prune(self)
#     139 self.original_results["output"][idx] = self.original_results["output"][idx].to(self.device)
#     140 self.current_results["output"][idx] = self.current_results["output"][idx].to(self.device)
# --> 141 self.prune(self.original_results["layer"][idx], layer, self.original_results["output"][idx],
#     142            self.current_results["output"][idx])
#     143 self.original_results["output"][idx] = self.original_results["output"][idx].to('cpu')
#     144 self.current_results["output"][idx] = self.current_results["output"][idx].to('cpu')
#
# File ~/Github/DiscoverVoice/SuperDemucs/utils/prune_utils/concern_identification.py:51, in ConcernIdentification.prune(self, ref_model, model, original_output, output)
#      47 shape = current_weight.shape
#      49 output_loss = output - original_output
#      50 positive_loss_mask = (
# ---> 51     torch.all(output_loss > 0, dim=0).unsqueeze(1).expand(-1, shape[1])
#      52 )
#      54 original_weight_std = safe_std(original_weight, dim=1, keepdim=True)
#      55 current_weight_std = safe_std(
#      56     current_weight,
#      57     epsilon=original_weight_std,
#    (...)
#      60     keepdim=True,
#      61 )
#
# RuntimeError: expand(CUDABoolType{[256, 1, 256]}, size=[-1, 1024]): the number of sizes provided (2) must be greater or equal to the number of dimensions in the tensor (3)

# %%
store_path = os.path.join(cfg.results_path, f'model_mdx23c(after prune).ckpt')
state_dict = mdx23c.state_dict()
torch.save(state_dict, store_path)
